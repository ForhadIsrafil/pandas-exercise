# %%
import pandas as pd
import numpy as np
import requests
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(data, index=labels)

# %%
# df.pivot_table(index='animal', columns='visits', values='age', aggfunc='mean', fill_value='haha')
# dti = pd.date_range(start='2015-01-01', end='2015-12-31', freq='B') 
# s = pd.Series(np.random.rand(len(dti)), index=dti)
# s.resample('M').mean()

# %%
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}
cookies = {"session-id": "138-3195592-9663251"}
amazon_url_res = requests.get('https://www.amazon.com/Logitech-Prodigy-Wired-Gaming-Mouse/dp/B01M26YUKO?pf_rd_r=RRCV4QZVN1CXTB891XQF&pf_rd_p=1f552c7a-1af2-4608-bc6f-ba06ca3c43ac&pd_rd_r=4d43df76-06a4-4b72-9ed8-550cb5e164f7&pd_rd_w=N4jDn&pd_rd_wg=gguKS&ref_=pd_gw_unk', cookies=cookies, headers=header)
amazon_df = pd.read_html(amazon_url_res.content.decode('utf-8'))
amazon_df[4]
# Out:
#                    0                                                  1  \
# 0                NaN  This item Logitech G203 Prodigy RGB Wired Gami...
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3    Customer Rating                          4.6 out of 5 stars (5281)
# 4              Price                                        From $29.99
# 5            Sold By                       Available from these sellers
# 6              Color                                              Black
# 7  Hardware Platform                                             PC, PC
# 8    Item Dimensions                          1.50 x 2.45 x 4.59 inches
# 9        Item Weight                                        3.00 ounces
#
#                                                    2  \
# 0  AmazonBasics PC Programmable Gaming Mouse | Ad...
# 1                                                NaN
# ...
